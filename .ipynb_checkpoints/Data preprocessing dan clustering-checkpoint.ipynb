# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
import numpy as np

# %%
dataset = pd.read_excel('dataset.xlsx')
dataset = pd.DataFrame(dataset)
dataset
# Out:
#                   Timestamp Mohon sebutkan nama atau inisial Anda  \
# 0   2022-04-08 17:36:21.407                                     z
# 1   2022-04-08 18:00:11.520                                    JC
# 2   2022-04-08 18:12:49.543                                    RH
# 3   2022-04-08 18:29:51.912                                tubsul
# 4   2022-04-08 18:43:27.998                                     H
# ..                      ...                                   ...
# 96  2022-04-14 12:37:16.232                                     M
# 97  2022-04-14 13:56:17.479                        mutia_putuhena
# 98  2022-04-14 14:28:16.813                                  rony
# 99  2022-04-14 15:45:09.348                                   Tan
# 100 2022-04-14 16:21:50.286                                 diani
#
#     Nomer HP yang bisa dihubungi (opsional) Apakah jenis kelamin Anda?  \
# 0                                       NaN                  Perempuan
# 1                                       NaN                  Laki-Laki
# 2                                       NaN                  Laki-Laki
# 3                              082121616196                  Laki-Laki
# 4                                         -                  Perempuan
# ..                                      ...                        ...
# 96                                      NaN                  Perempuan
# 97                             081223445581                  Perempuan
# 98                             085643410672                  Laki-Laki
# 99                                      NaN                  Perempuan
# 100                             08119418811                  Perempuan
#
#     Berapakah usia Anda sekarang? Di mana domisili Anda sekarang?  \
# 0                   18 - 25 tahun                           Bogor
# 1                   26 - 35 tahun                         Jakarta
# 2                   18 - 25 tahun                         Jakarta
# 3                   18 - 25 tahun                           Depok
# 4                   18 - 25 tahun                           Depok
# ..                            ...                             ...
# 96                  18 - 25 tahun                         Jakarta
# 97                  26 - 35 tahun                         Jakarta
# 98                  26 - 35 tahun                         Jakarta
# 99                  18 - 25 tahun                         Jakarta
# 100                 36 - 45 tahun                         Jakarta
#
#     Apakah status Anda sekarang? Apakah pekerjaan utama Anda sekarang?  \
# 0                         Lajang                             Mahasiswa
# 1                         Lajang                        Pegawai Swasta
# 2                         Lajang                             Mahasiswa
# 3                         Lajang                             Mahasiswa
# 4                         Lajang                             Mahasiswa
# ..                           ...                                   ...
# 96                        Lajang                        Pegawai Swasta
# 97                        Lajang                        Pegawai Swasta
# 98                        Lajang                        Pegawai Swasta
# 99                        Lajang                        Pegawai Negeri
# 100                Sudah menikah                        Pegawai Swasta
#
#     Berapakah kisaran pendapatan Anda perbulannya?  \
# 0                                Rp0 - Rp2.500.000
# 1                       Rp5.000.000 - Rp10.000.000
# 2                                Rp0 - Rp2.500.000
# 3                       Rp5.000.000 - Rp10.000.000
# 4                       Rp5.000.000 - Rp10.000.000
# ..                                             ...
# 96                     Rp10.000.000 - Rp20.000.000
# 97                      Rp5.000.000 - Rp10.000.000
# 98                      Rp5.000.000 - Rp10.000.000
# 99                      Rp5.000.000 - Rp10.000.000
# 100                    Rp10.000.000 - Rp20.000.000
#
#     Berapakah kisaran pengeluaran Anda perbulannya?  ...  \
# 0                                 Rp0 - Rp2.500.000  ...
# 1                         Rp2.500.000 - Rp5.000.000  ...
# 2                                 Rp0 - Rp2.500.000  ...
# 3                         Rp2.500.000 - Rp5.000.000  ...
# 4                        Rp5.000.000 - Rp10.000.000  ...
# ..                                              ...  ...
# 96                        Rp2.500.000 - Rp5.000.000  ...
# 97                       Rp5.000.000 - Rp10.000.000  ...
# 98                        Rp2.500.000 - Rp5.000.000  ...
# 99                        Rp2.500.000 - Rp5.000.000  ...
# 100                      Rp5.000.000 - Rp10.000.000  ...
#
#     Servis apa yang paling sering Anda lakukan dengan Ride Hailing app Anda? [3]  \
# 0                                         Transportasi
# 1                                   Pembayaran tagihan
# 2                                   Pembayaran tagihan
# 3                                    Pembelian lainnya
# 4                                      Belanja Bulanan
# ..                                                 ...
# 96                                  Pembayaran tagihan
# 97                                     Belanja Bulanan
# 98                                   Pembelian lainnya
# 99                                     Belanja Bulanan
# 100                                 Pembayaran tagihan
#
#     Servis apa yang paling sering Anda lakukan dengan Ride Hailing app Anda? [4]  \
# 0                                      Belanja Bulanan
# 1                                    Pemesanan makanan
# 2                                    Pemesanan makanan
# 3                                         Transportasi
# 4                                    Pembelian lainnya
# ..                                                 ...
# 96                                     Belanja Bulanan
# 97                                   Pemesanan makanan
# 98                                   Pemesanan makanan
# 99                                        Transportasi
# 100                                       Transportasi
#
#     Servis apa yang paling sering Anda lakukan dengan Ride Hailing app Anda? [5]  \
# 0                                   Pembayaran tagihan
# 1                                         Transportasi
# 2                                         Transportasi
# 3                                    Pemesanan makanan
# 4                                   Pembayaran tagihan
# ..                                                 ...
# 96                                   Pembelian lainnya
# 97                                        Transportasi
# 98                                     Belanja Bulanan
# 99                                   Pemesanan makanan
# 100                                  Pemesanan makanan
#
#     Apa alasan utama Anda menggunakan Ride Hailing app? [Praktis dan cepat]  \
# 0                                                  1.0
# 1                                                  5.0
# 2                                                  5.0
# 3                                                  5.0
# 4                                                  2.0
# ..                                                 ...
# 96                                                 1.0
# 97                                                 4.0
# 98                                                 5.0
# 99                                                 5.0
# 100                                                5.0
#
#     Apa alasan utama Anda menggunakan Ride Hailing app? [Menghindari kemacetan]  \
# 0                                                  2.0
# 1                                                  4.0
# 2                                                  4.0
# 3                                                  4.0
# 4                                                  4.0
# ..                                                 ...
# 96                                                 2.0
# 97                                                 5.0
# 98                                                 4.0
# 99                                                 3.0
# 100                                                4.0
#
#     Apa alasan utama Anda menggunakan Ride Hailing app? [Tidak memiliki kendaraan pribadi]  \
# 0                                                  4.0
# 1                                                  2.0
# 2                                                  2.0
# 3                                                  1.0
# 4                                                  3.0
# ..                                                 ...
# 96                                                 3.0
# 97                                                 2.0
# 98                                                 3.0
# 99                                                 1.0
# 100                                                3.0
#
#     Apa alasan utama Anda menggunakan Ride Hailing app? [Banyak diskon/potongan harga]  \
# 0                                                  3.0
# 1                                                  3.0
# 2                                                  1.0
# 3                                                  3.0
# 4                                                  1.0
# ..                                                 ...
# 96                                                 4.0
# 97                                                 3.0
# 98                                                 2.0
# 99                                                 4.0
# 100                                                2.0
#
#     Apa alasan utama Anda menggunakan Ride Hailing app? [Banyak teman yang memakai juga]  \
# 0                                                  5.0
# 1                                                  1.0
# 2                                                  3.0
# 3                                                  2.0
# 4                                                  5.0
# ..                                                 ...
# 96                                                 5.0
# 97                                                 1.0
# 98                                                 1.0
# 99                                                 2.0
# 100                                                1.0
#
#      Apakah keterhubungan Ride Hailing app dengan e-Wallet mempengaruhi pilihan Anda?  \
# 0                                                   Ya
# 1                                                   Ya
# 2                                                   Ya
# 3                                                   Ya
# 4                                                   Ya
# ..                                                 ...
# 96                                                  Ya
# 97                                                  Ya
# 98                                                  Ya
# 99                                                  Ya
# 100                                                 Ya
#
#      Seberapa pentingkah keterhubungan antara e-Wallet dan Ride Hailing app bagi Anda dalam menentukan penggunaannya
# 0                                                  5.0
# 1                                                  4.0
# 2                                                  4.0
# 3                                                  5.0
# 4                                                  1.0
# ..                                                 ...
# 96                                                 5.0
# 97                                                 5.0
# 98                                                 4.0
# 99                                                 5.0
# 100                                                5.0
#
# [101 rows x 40 columns]

# %%
dataset.columns
# Out:
# Index(['Timestamp', 'Mohon sebutkan nama atau inisial Anda',
#        'Nomer HP yang bisa dihubungi (opsional)', 'Apakah jenis kelamin Anda?',
#        'Berapakah usia Anda sekarang?', 'Di mana domisili Anda sekarang?',
#        'Apakah status Anda sekarang?', 'Apakah pekerjaan utama Anda sekarang?',
#        'Berapakah kisaran pendapatan Anda perbulannya?',
#        'Berapakah kisaran pengeluaran Anda perbulannya?',
#        'Manakah dari e-Wallet ini yang pernah Anda gunakan?',
#        'Manakah dari e-Wallet ini yang paling sering Anda gunakan?',
#        'Seberapa sering Anda menggunakan e-Wallet dalam seminggu?',
#        'Penggunaan apa yang paling sering anda lakukan dengan e-Wallet Anda? [1]',
#        'Penggunaan apa yang paling sering anda lakukan dengan e-Wallet Anda? [2]',
#        'Penggunaan apa yang paling sering anda lakukan dengan e-Wallet Anda? [3]',
#        'Penggunaan apa yang paling sering anda lakukan dengan e-Wallet Anda? [4]',
#        'Penggunaan apa yang paling sering anda lakukan dengan e-Wallet Anda? [5]',
#        'Apa alasan utama Anda menggunakan e-Wallet? [Penggunaan yang praktis]',
#        'Apa alasan utama Anda menggunakan e-Wallet? [Kecepatan transaksi]',
#        'Apa alasan utama Anda menggunakan e-Wallet? [Diterima di berbagi merchant]',
#        'Apa alasan utama Anda menggunakan e-Wallet? [Banyak diskon/potongan harga]',
#        'Apa alasan utama Anda menggunakan e-Wallet? [Banyak teman yang memakai juga]',
#        'Apa alasan utama Anda menggunakan e-Wallet? [Kemudahan channel untuk topup]',
#        'Apa alasan utama Anda menggunakan e-Wallet? [Desain visual yang menarik]',
#        'Seberapa banyak pengeluaran rata-rata Anda melalui e-Wallet dalam sebulan?',
#        'Manakah dari Ride Hailing app ini yang pernah Anda gunakan?',
#        'Manakah dari Ride Hailing app ini yang paling sering Anda gunakan?',
#        'Servis apa yang paling sering Anda lakukan dengan Ride Hailing app Anda? [1]',
#        'Servis apa yang paling sering Anda lakukan dengan Ride Hailing app Anda? [2]',
#        'Servis apa yang paling sering Anda lakukan dengan Ride Hailing app Anda? [3]',
#        'Servis apa yang paling sering Anda lakukan dengan Ride Hailing app Anda? [4]',
#        'Servis apa yang paling sering Anda lakukan dengan Ride Hailing app Anda? [5]',
#        'Apa alasan utama Anda menggunakan Ride Hailing app? [Praktis dan cepat]',
#        'Apa alasan utama Anda menggunakan Ride Hailing app? [Menghindari kemacetan]',
#        'Apa alasan utama Anda menggunakan Ride Hailing app? [Tidak memiliki kendaraan pribadi]',
#        'Apa alasan utama Anda menggunakan Ride Hailing app? [Banyak diskon/potongan harga]',
#        'Apa alasan utama Anda menggunakan Ride Hailing app? [Banyak teman yang memakai juga]',
#        'Apakah keterhubungan Ride Hailing app dengan e-Wallet mempengaruhi pilihan Anda?',
#        'Seberapa pentingkah keterhubungan antara e-Wallet dan Ride Hailing app bagi Anda dalam menentukan penggunaannya'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#        Apa alasan utama Anda menggunakan e-Wallet? [Penggunaan yang praktis]  \
# count                                         101.000000
# mean                                            5.940594
# std                                             1.765343
# min                                             1.000000
# 25%                                             6.000000
# 50%                                             7.000000
# 75%                                             7.000000
# max                                             7.000000
#
#        Apa alasan utama Anda menggunakan e-Wallet? [Kecepatan transaksi]  \
# count                                         101.000000
# mean                                            5.198020
# std                                             1.476616
# min                                             1.000000
# 25%                                             5.000000
# 50%                                             6.000000
# 75%                                             6.000000
# max                                             7.000000
#
#        Apa alasan utama Anda menggunakan e-Wallet? [Diterima di berbagi merchant]  \
# count                                         101.000000
# mean                                            4.445545
# std                                             1.292093
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             7.000000
#
#        Apa alasan utama Anda menggunakan e-Wallet? [Banyak diskon/potongan harga]  \
# count                                         101.000000
# mean                                            4.217822
# std                                             1.584954
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             7.000000
#
#        Apa alasan utama Anda menggunakan e-Wallet? [Banyak teman yang memakai juga]  \
# count                                         101.000000
# mean                                            2.762376
# std                                             1.429325
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             3.000000
# max                                             7.000000
#
#        Apa alasan utama Anda menggunakan e-Wallet? [Kemudahan channel untuk topup]  \
# count                                         101.000000
# mean                                            3.346535
# std                                             1.506225
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             7.000000
#
#        Apa alasan utama Anda menggunakan e-Wallet? [Desain visual yang menarik]  \
# count                                         101.000000
# mean                                            2.089109
# std                                             1.822630
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                             7.000000
#
#        Apa alasan utama Anda menggunakan Ride Hailing app? [Praktis dan cepat]  \
# count                                         101.000000
# mean                                            4.158416
# std                                             1.369180
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        Apa alasan utama Anda menggunakan Ride Hailing app? [Menghindari kemacetan]  \
# count                                         101.000000
# mean                                            3.287129
# std                                             0.993344
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Apa alasan utama Anda menggunakan Ride Hailing app? [Tidak memiliki kendaraan pribadi]  \
# count                                         101.000000
# mean                                            2.396040
# std                                             1.158268
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Apa alasan utama Anda menggunakan Ride Hailing app? [Banyak diskon/potongan harga]  \
# count                                         101.000000
# mean                                            3.099010
# std                                             1.090917
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Apa alasan utama Anda menggunakan Ride Hailing app? [Banyak teman yang memakai juga]  \
# count                                         101.000000
# mean                                            2.059406
# std                                             1.412953
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                             5.000000
#
#        Seberapa pentingkah keterhubungan antara e-Wallet dan Ride Hailing app bagi Anda dalam menentukan penggunaannya
# count                                         101.000000
# mean                                            4.495050
# std                                             0.820046
# min                                             1.000000
# 25%                                             4.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000

# %%
dataset = dataset[['Apakah jenis kelamin Anda?', 'Berapakah usia Anda sekarang?', 'Apakah pekerjaan utama Anda sekarang?', 'Berapakah kisaran pendapatan Anda perbulannya?',
       'Berapakah kisaran pengeluaran Anda perbulannya?', 'Manakah dari e-Wallet ini yang paling sering Anda gunakan?', 'Manakah dari Ride Hailing app ini yang paling sering Anda gunakan?']]

# %%
dataset.columns = ['jenis_kelamin', 'usia', 'pekerjaan', 'pendapatan_per_bulan', 'pengeluaran_per_bulan', 'favorite_ewallet', 'favorite_ride_hailing_app']

# %%
dataset
# Out:
#     jenis_kelamin           usia       pekerjaan         pendapatan_per_bulan  \
# 0       Perempuan  18 - 25 tahun       Mahasiswa            Rp0 - Rp2.500.000
# 1       Laki-Laki  26 - 35 tahun  Pegawai Swasta   Rp5.000.000 - Rp10.000.000
# 2       Laki-Laki  18 - 25 tahun       Mahasiswa            Rp0 - Rp2.500.000
# 3       Laki-Laki  18 - 25 tahun       Mahasiswa   Rp5.000.000 - Rp10.000.000
# 4       Perempuan  18 - 25 tahun       Mahasiswa   Rp5.000.000 - Rp10.000.000
# ..            ...            ...             ...                          ...
# 96      Perempuan  18 - 25 tahun  Pegawai Swasta  Rp10.000.000 - Rp20.000.000
# 97      Perempuan  26 - 35 tahun  Pegawai Swasta   Rp5.000.000 - Rp10.000.000
# 98      Laki-Laki  26 - 35 tahun  Pegawai Swasta   Rp5.000.000 - Rp10.000.000
# 99      Perempuan  18 - 25 tahun  Pegawai Negeri   Rp5.000.000 - Rp10.000.000
# 100     Perempuan  36 - 45 tahun  Pegawai Swasta  Rp10.000.000 - Rp20.000.000
#
#           pengeluaran_per_bulan favorite_ewallet favorite_ride_hailing_app
# 0             Rp0 - Rp2.500.000        ShopeePay                ShopeeFood
# 1     Rp2.500.000 - Rp5.000.000            GoPay                     Gojek
# 2             Rp0 - Rp2.500.000              Ovo                      Grab
# 3     Rp2.500.000 - Rp5.000.000            GoPay                     Gojek
# 4    Rp5.000.000 - Rp10.000.000        ShopeePay                ShopeeFood
# ..                          ...              ...                       ...
# 96    Rp2.500.000 - Rp5.000.000              Ovo                      Grab
# 97   Rp5.000.000 - Rp10.000.000              Ovo                      Grab
# 98    Rp2.500.000 - Rp5.000.000        ShopeePay                      Grab
# 99    Rp2.500.000 - Rp5.000.000            GoPay                      Grab
# 100  Rp5.000.000 - Rp10.000.000            GoPay                     Gojek
#
# [101 rows x 7 columns]

# %%
dataset.isna().sum()
# Out:
# jenis_kelamin                0
# usia                         0
# pekerjaan                    0
# pendapatan_per_bulan         0
# pengeluaran_per_bulan        0
# favorite_ewallet             0
# favorite_ride_hailing_app    0
# dtype: int64

# %%
dataset
# Out:
#     jenis_kelamin           usia       pekerjaan         pendapatan_per_bulan  \
# 0       Perempuan  18 - 25 tahun       Mahasiswa            Rp0 - Rp2.500.000
# 1       Laki-Laki  26 - 35 tahun  Pegawai Swasta   Rp5.000.000 - Rp10.000.000
# 2       Laki-Laki  18 - 25 tahun       Mahasiswa            Rp0 - Rp2.500.000
# 3       Laki-Laki  18 - 25 tahun       Mahasiswa   Rp5.000.000 - Rp10.000.000
# 4       Perempuan  18 - 25 tahun       Mahasiswa   Rp5.000.000 - Rp10.000.000
# ..            ...            ...             ...                          ...
# 96      Perempuan  18 - 25 tahun  Pegawai Swasta  Rp10.000.000 - Rp20.000.000
# 97      Perempuan  26 - 35 tahun  Pegawai Swasta   Rp5.000.000 - Rp10.000.000
# 98      Laki-Laki  26 - 35 tahun  Pegawai Swasta   Rp5.000.000 - Rp10.000.000
# 99      Perempuan  18 - 25 tahun  Pegawai Negeri   Rp5.000.000 - Rp10.000.000
# 100     Perempuan  36 - 45 tahun  Pegawai Swasta  Rp10.000.000 - Rp20.000.000
#
#           pengeluaran_per_bulan favorite_ewallet favorite_ride_hailing_app
# 0             Rp0 - Rp2.500.000        ShopeePay                ShopeeFood
# 1     Rp2.500.000 - Rp5.000.000            GoPay                     Gojek
# 2             Rp0 - Rp2.500.000              Ovo                      Grab
# 3     Rp2.500.000 - Rp5.000.000            GoPay                     Gojek
# 4    Rp5.000.000 - Rp10.000.000        ShopeePay                ShopeeFood
# ..                          ...              ...                       ...
# 96    Rp2.500.000 - Rp5.000.000              Ovo                      Grab
# 97   Rp5.000.000 - Rp10.000.000              Ovo                      Grab
# 98    Rp2.500.000 - Rp5.000.000        ShopeePay                      Grab
# 99    Rp2.500.000 - Rp5.000.000            GoPay                      Grab
# 100  Rp5.000.000 - Rp10.000.000            GoPay                     Gojek
#
# [101 rows x 7 columns]

# %%
dataset['jenis_kelamin'].unique()
# Out:
# array(['Perempuan', 'Laki-Laki'], dtype=object)

# %%
dataset['jenis_kelamin'] = dataset['jenis_kelamin'].replace(['Perempuan'],'Wanita')
dataset['jenis_kelamin'] = dataset['jenis_kelamin'].replace(['Laki-Laki'],'Pria')
# Out:
# C:\Users\MSI\AppData\Local\Temp/ipykernel_17128/345257282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['jenis_kelamin'] = dataset['jenis_kelamin'].replace(['Perempuan'],'Wanita')
# C:\Users\MSI\AppData\Local\Temp/ipykernel_17128/345257282.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['jenis_kelamin'] = dataset['jenis_kelamin'].replace(['Laki-Laki'],'Pria')

# %%
dataset['usia'].unique()
# Out:
# array(['18 - 25 tahun', '26 - 35 tahun', '46 - 55 tahun', '> 55 tahun',
#        '36 - 45 tahun'], dtype=object)

# %%
dataset['pekerjaan'].unique()
# Out:
# array(['Mahasiswa', 'Pegawai Swasta', 'Wirausaha', 'Pegawai Negeri',
#        'Pelajar', 'Asisten Rumah tangga', 'Ibu Rumah Tangga',
#        'Ibu rumah tangga', 'Mahasiswa S2'], dtype=object)

# %%
dataset['pekerjaan'] = dataset['pekerjaan'].replace(['Mahasiswa S2'],'Pelajar/Mahasiswa')
dataset['pekerjaan'] = dataset['pekerjaan'].replace(['Mahasiswa'],'Pelajar/Mahasiswa')
dataset['pekerjaan'] = dataset['pekerjaan'].replace(['Pelajar'],'Pelajar/Mahasiswa')
dataset['pekerjaan'] = dataset['pekerjaan'].replace(['Asisten Rumah tangga'],'Lainnya')
dataset['pekerjaan'] = dataset['pekerjaan'].replace(['Ibu Rumah Tangga'],'Lainnya')
dataset['pekerjaan'] = dataset['pekerjaan'].replace(['Ibu rumah tangga'],'Lainnya')
# Out:
# C:\Users\MSI\AppData\Local\Temp/ipykernel_17128/601985491.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['pekerjaan'] = dataset['pekerjaan'].replace(['Mahasiswa S2'],'Pelajar/Mahasiswa')
# C:\Users\MSI\AppData\Local\Temp/ipykernel_17128/601985491.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['pekerjaan'] = dataset['pekerjaan'].replace(['Mahasiswa'],'Pelajar/Mahasiswa')
# C:\Users\MSI\AppData\Local\Temp/ipykernel_17128/601985491.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['pekerjaan'] = dataset['pekerjaan'].replace(['Pelajar'],'Pelajar/Mahasiswa')
# C:\Users\MSI\AppData\Local\Temp/ipykernel_17128/601985491.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['pekerjaan'] = dataset['pekerjaan'].replace(['Asisten Rumah tangga'],'Lainnya')
# C:\Users\MSI\AppData\Local\Temp/ipykernel_17128/601985491.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['pekerjaan'] = dataset['pekerjaan'].replace(['Ibu Rumah Tangga'],'Lainnya')
# C:\Users\MSI\AppData\Local\Temp/ipykernel_17128/601985491.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['pekerjaan'] = dataset['pekerjaan'].replace(['Ibu rumah tangga'],'Lainnya')

# %%
dataset['pendapatan_per_bulan'].unique()
# Out:
# array(['Rp0 - Rp2.500.000', 'Rp5.000.000 - Rp10.000.000', '>Rp20.000.000',
#        'Rp10.000.000 - Rp20.000.000', 'Rp2.500.000 - Rp5.000.000'],
#       dtype=object)

# %%
dataset['pengeluaran_per_bulan'].unique()
# Out:
# array(['Rp0 - Rp2.500.000', 'Rp2.500.000 - Rp5.000.000',
#        'Rp5.000.000 - Rp10.000.000', 'Rp10.000.000 - Rp20.000.000',
#        '>Rp20.000.000'], dtype=object)

# %%
dataset['favorite_ewallet'].unique()
# Out:
# array(['ShopeePay', 'GoPay', 'Ovo', 'Dana', 'LinkAja'], dtype=object)

# %%
dataset['favorite_ride_hailing_app'].unique()
# Out:
# array(['ShopeeFood', 'Gojek', 'Grab', 'TravelokaEats'], dtype=object)

# %%
dataset['pekerjaan'].unique()
# Out:
# array(['Pelajar/Mahasiswa', 'Pegawai Swasta', 'Wirausaha',
#        'Pegawai Negeri', 'Lainnya'], dtype=object)

# %%
dataset.head()
# Out:
#   jenis_kelamin           usia          pekerjaan        pendapatan_per_bulan  \
# 0        Wanita  18 - 25 tahun  Pelajar/Mahasiswa           Rp0 - Rp2.500.000
# 1          Pria  26 - 35 tahun     Pegawai Swasta  Rp5.000.000 - Rp10.000.000
# 2          Pria  18 - 25 tahun  Pelajar/Mahasiswa           Rp0 - Rp2.500.000
# 3          Pria  18 - 25 tahun  Pelajar/Mahasiswa  Rp5.000.000 - Rp10.000.000
# 4        Wanita  18 - 25 tahun  Pelajar/Mahasiswa  Rp5.000.000 - Rp10.000.000
#
#         pengeluaran_per_bulan favorite_ewallet favorite_ride_hailing_app
# 0           Rp0 - Rp2.500.000        ShopeePay                ShopeeFood
# 1   Rp2.500.000 - Rp5.000.000            GoPay                     Gojek
# 2           Rp0 - Rp2.500.000              Ovo                      Grab
# 3   Rp2.500.000 - Rp5.000.000            GoPay                     Gojek
# 4  Rp5.000.000 - Rp10.000.000        ShopeePay                ShopeeFood

# %%
categorical = dataset.dtypes==object

# %%
clustering_dataset = dataset.copy()

# %%
categorical = clustering_dataset.dtypes==object
categorical_cols = clustering_dataset.columns[categorical].tolist()
clustering_dataset[categorical_cols] = clustering_dataset[categorical_cols].apply(lambda col: LabelEncoder().fit_transform(col))
clustering_dataset[categorical_cols].head()
clustering_dataset
# Out:
#      jenis_kelamin  usia  pekerjaan  pendapatan_per_bulan  \
# 0                1     0          3                     1
# 1                0     1          2                     4
# 2                0     0          3                     1
# 3                0     0          3                     4
# 4                1     0          3                     4
# ..             ...   ...        ...                   ...
# 96               1     0          2                     2
# 97               1     1          2                     4
# 98               0     1          2                     4
# 99               1     0          1                     4
# 100              1     2          2                     2
#
#      pengeluaran_per_bulan  favorite_ewallet  favorite_ride_hailing_app
# 0                        1                 4                          2
# 1                        3                 1                          0
# 2                        1                 3                          1
# 3                        3                 1                          0
# 4                        4                 4                          2
# ..                     ...               ...                        ...
# 96                       3                 3                          1
# 97                       4                 3                          1
# 98                       3                 4                          1
# 99                       3                 1                          1
# 100                      4                 1                          0
#
# [101 rows x 7 columns]

# %%
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(clustering_dataset)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
kmeanModel = KMeans(n_clusters=3)
kmeanModel.fit(clustering_dataset)
# Out:
# KMeans(n_clusters=3)

# %%
dataset['cluster']=kmeanModel.predict(clustering_dataset)
# Out:
# C:\Users\MSI\AppData\Local\Temp/ipykernel_17128/3349076807.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['cluster']=kmeanModel.predict(clustering_dataset)

# %%
dataset
# Out:
#     jenis_kelamin           usia          pekerjaan  \
# 0          Wanita  18 - 25 tahun  Pelajar/Mahasiswa
# 1            Pria  26 - 35 tahun     Pegawai Swasta
# 2            Pria  18 - 25 tahun  Pelajar/Mahasiswa
# 3            Pria  18 - 25 tahun  Pelajar/Mahasiswa
# 4          Wanita  18 - 25 tahun  Pelajar/Mahasiswa
# ..            ...            ...                ...
# 96         Wanita  18 - 25 tahun     Pegawai Swasta
# 97         Wanita  26 - 35 tahun     Pegawai Swasta
# 98           Pria  26 - 35 tahun     Pegawai Swasta
# 99         Wanita  18 - 25 tahun     Pegawai Negeri
# 100        Wanita  36 - 45 tahun     Pegawai Swasta
#
#             pendapatan_per_bulan       pengeluaran_per_bulan favorite_ewallet  \
# 0              Rp0 - Rp2.500.000           Rp0 - Rp2.500.000        ShopeePay
# 1     Rp5.000.000 - Rp10.000.000   Rp2.500.000 - Rp5.000.000            GoPay
# 2              Rp0 - Rp2.500.000           Rp0 - Rp2.500.000              Ovo
# 3     Rp5.000.000 - Rp10.000.000   Rp2.500.000 - Rp5.000.000            GoPay
# 4     Rp5.000.000 - Rp10.000.000  Rp5.000.000 - Rp10.000.000        ShopeePay
# ..                           ...                         ...              ...
# 96   Rp10.000.000 - Rp20.000.000   Rp2.500.000 - Rp5.000.000              Ovo
# 97    Rp5.000.000 - Rp10.000.000  Rp5.000.000 - Rp10.000.000              Ovo
# 98    Rp5.000.000 - Rp10.000.000   Rp2.500.000 - Rp5.000.000        ShopeePay
# 99    Rp5.000.000 - Rp10.000.000   Rp2.500.000 - Rp5.000.000            GoPay
# 100  Rp10.000.000 - Rp20.000.000  Rp5.000.000 - Rp10.000.000            GoPay
#
#     favorite_ride_hailing_app  cluster
# 0                  ShopeeFood        2
# 1                       Gojek        1
# 2                        Grab        2
# 3                       Gojek        1
# 4                  ShopeeFood        0
# ..                        ...      ...
# 96                       Grab        0
# 97                       Grab        0
# 98                       Grab        0
# 99                       Grab        1
# 100                     Gojek        1
#
# [101 rows x 8 columns]

# %%
dataset['cluster'] = dataset['cluster'].replace(2,3)
dataset['cluster'] = dataset['cluster'].replace(1,2)
dataset['cluster'] = dataset['cluster'].replace(0,1)
# Out:
# C:\Users\MSI\AppData\Local\Temp/ipykernel_17128/1408816580.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['cluster'] = dataset['cluster'].replace(2,3)
# C:\Users\MSI\AppData\Local\Temp/ipykernel_17128/1408816580.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['cluster'] = dataset['cluster'].replace(1,2)
# C:\Users\MSI\AppData\Local\Temp/ipykernel_17128/1408816580.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['cluster'] = dataset['cluster'].replace(0,1)

# %%
dataset.head()
# Out:
#   jenis_kelamin           usia          pekerjaan        pendapatan_per_bulan  \
# 0        Wanita  18 - 25 tahun  Pelajar/Mahasiswa           Rp0 - Rp2.500.000
# 1          Pria  26 - 35 tahun     Pegawai Swasta  Rp5.000.000 - Rp10.000.000
# 2          Pria  18 - 25 tahun  Pelajar/Mahasiswa           Rp0 - Rp2.500.000
# 3          Pria  18 - 25 tahun  Pelajar/Mahasiswa  Rp5.000.000 - Rp10.000.000
# 4        Wanita  18 - 25 tahun  Pelajar/Mahasiswa  Rp5.000.000 - Rp10.000.000
#
#         pengeluaran_per_bulan favorite_ewallet favorite_ride_hailing_app  \
# 0           Rp0 - Rp2.500.000        ShopeePay                ShopeeFood
# 1   Rp2.500.000 - Rp5.000.000            GoPay                     Gojek
# 2           Rp0 - Rp2.500.000              Ovo                      Grab
# 3   Rp2.500.000 - Rp5.000.000            GoPay                     Gojek
# 4  Rp5.000.000 - Rp10.000.000        ShopeePay                ShopeeFood
#
#    cluster
# 0        3
# 1        2
# 2        3
# 3        2
# 4        1

# %%
clusters = ['Cluster 1', 'Cluster 2', 'Cluster 3']

jml_c1 = len(dataset.loc[dataset['cluster'] == 1])
jml_c2 = len(dataset.loc[dataset['cluster'] == 2])
jml_c3 = len(dataset.loc[dataset['cluster'] == 3])

data = [jml_c1, jml_c2, jml_c3]
 
 
# Creating explode data
explode = (0.0, 0.1, 0.0)
 
# Creating color parameters
colors = ( "red", "green", "blue")
 
# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "black" }
 
# Creating autocpt arguments
def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)
 
# Creating plot
fig, ax = plt.subplots(figsize =(10, 7))
wedges, texts, autotexts = ax.pie(data,
                                  autopct = lambda pct: func(pct, data),
                                  explode = explode,
                                  labels = clusters,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="black"))
fig.set_facecolor('white')
 
# Adding legend
ax.legend(wedges, clusters,
          title ="Clusters",
          loc ="center left",
          bbox_to_anchor =(1, 0, 0.5, 1))
 
plt.setp(autotexts, size = 8, weight ="bold")
ax.set_title("Customizing pie chart")
 
# show plot
plt.show()

# %%
dataset.loc[dataset['cluster'] == 1]
# Out:
# 36
