# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
import numpy as np
import seaborn as sns

# %%
dataset = pd.read_excel('clustered_dataset.xlsx')

# %%
clusters = ['Cluster 1', 'Cluster 2', 'Cluster 3']

jml_c1 = int(len(dataset.loc[dataset['cluster'] == 1]))
jml_c2 = int(len(dataset.loc[dataset['cluster'] == 2]))
jml_c3 = int(len(dataset.loc[dataset['cluster'] == 3]))

data = np.array([jml_c1, jml_c2, jml_c3])

colors = ['yellowgreen', 'gold', 'lightskyblue']

explode = (0.05, 0.1, 0.0)

def absolute_value(val):
    a  = np.round(val/100.*data.sum(), 0)
    return int(a)

wp = { 'linewidth' : 1, 'edgecolor' : "black" }
fig, ax = plt.subplots(figsize =(10, 7))

wedges, texts, autotexts = ax.pie(data,
                                  autopct = absolute_value,
                                  explode = explode,
                                  labels = clusters,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="black"))
fig.set_facecolor('white')

ax.legend(wedges, clusters,
          title ="Clusters",
          loc ="center left",
          bbox_to_anchor =(1, 0, 0.5, 1))
 
plt.setp(autotexts, size = 8, weight ="bold")
ax.set_title("Hasil clustering")


plt.axis('equal')
plt.savefig('Pie chart hasil clustering.png')

# %% [markdown]
# <h3>CLUSTER 1<H3>

# %%
cluster1 = pd.read_excel('cluster1.xlsx')

# %%
cluster1.head()
# Out:
#    Unnamed: 0  index jenis_kelamin           usia          pekerjaan  \
# 0           0      4        Wanita  18 - 25 tahun  Pelajar/Mahasiswa
# 1           1      5        Wanita  18 - 25 tahun          Wirausaha
# 2           2      7        Wanita  18 - 25 tahun     Pegawai Swasta
# 3           3      8        Wanita  18 - 25 tahun     Pegawai Negeri
# 4           4     12        Wanita  18 - 25 tahun     Pegawai Swasta
#
#          pendapatan_per_bulan        pengeluaran_per_bulan favorite_ewallet  \
# 0  Rp5.000.000 - Rp10.000.000   Rp5.000.000 - Rp10.000.000        ShopeePay
# 1  Rp5.000.000 - Rp10.000.000    Rp2.500.000 - Rp5.000.000              Ovo
# 2  Rp5.000.000 - Rp10.000.000  Rp10.000.000 - Rp20.000.000              Ovo
# 3  Rp5.000.000 - Rp10.000.000   Rp5.000.000 - Rp10.000.000              Ovo
# 4  Rp5.000.000 - Rp10.000.000            Rp0 - Rp2.500.000              Ovo
#
#   favorite_ride_hailing_app pengeluaran_ewallet_sebulan tingkat_konsumerisme  \
# ...

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster1['jenis_kelamin'].value_counts().index, y=cluster1.jenis_kelamin.value_counts())
ax.set_title('Distribusi Jenis Kelamin Cluster 1')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_1/distribusi jenis kelamin cluster 1.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster1['usia'].value_counts().index, y=cluster1.usia.value_counts())
ax.set_title('Distribusi Usia Cluster 1')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_1/distribusi usia cluster 1.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster1['pekerjaan'].value_counts().index, y=cluster1.pekerjaan.value_counts())
ax.set_title('Distribusi Pekerjaan Cluster 1')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_1/distribusi pekerjaan cluster 1.jpg')

# %%
plt.figure(figsize=(12,5))
ax = sns.barplot(x=cluster1['pendapatan_per_bulan'].value_counts().index, y=cluster1.pendapatan_per_bulan.value_counts())
ax.set_title('Distribusi Pendapatan Per Bulan Cluster 1')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_1/distribusi pendapatan per bulan cluster 1.jpg')

# %%
plt.figure(figsize=(12,5))
ax = sns.barplot(x=cluster1['pengeluaran_per_bulan'].value_counts().index, y=cluster1.pengeluaran_per_bulan.value_counts())
ax.set_title('Distribusi Pengeluaran Per Bulan Cluster 1')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_1/distribusi pengeluaran per bulan cluster 1.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster1['tingkat_konsumerisme'].value_counts().index, y=cluster1.tingkat_konsumerisme.value_counts())
ax.set_title('Distribusi Tingkat Konsumerisme Cluster 1')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_1/distribusi tingkat konsumerisme cluster 1.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster1['favorite_ewallet'].value_counts().index, y=cluster1.favorite_ewallet.value_counts())
ax.set_title('Distribusi E-Wallet Paling Sering Digunakan Cluster 1')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_1/distribusi ewallet paling sering digunakan cluster 1.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster1['favorite_ride_hailing_app'].value_counts().index, y=cluster1.favorite_ride_hailing_app.value_counts())
ax.set_title('Distribusi Ride Hailing App Paling Sering Digunakan Cluster 1')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_1/distribusi Ride Hailing App Paling Sering Digunakan cluster 1.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster1['pengeluaran_ewallet_sebulan'].value_counts().index, y=cluster1.pengeluaran_ewallet_sebulan.value_counts())
ax.set_title('Distribusi Pengeluaran E-Wallet Per Bulan Paling Sering Digunakan Cluster 1')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_1/distribusi Pengeluaran E-Wallet Per Bulan Paling Sering Digunakan cluster 1.jpg')

# %% [markdown]
# <h3>CLUSTER 2<h3>

# %%
cluster2 = pd.read_excel('cluster2.xlsx')
cluster2.head()
# Out:
#    Unnamed: 0  index jenis_kelamin           usia          pekerjaan  \
# 0           0      0        Wanita  18 - 25 tahun  Pelajar/Mahasiswa
# 1           1      2          Pria  18 - 25 tahun  Pelajar/Mahasiswa
# 2           2      6        Wanita  18 - 25 tahun  Pelajar/Mahasiswa
# 3           3      9          Pria  18 - 25 tahun     Pegawai Swasta
# 4           4     11          Pria  26 - 35 tahun     Pegawai Swasta
#
#           pendapatan_per_bulan        pengeluaran_per_bulan favorite_ewallet  \
# 0            Rp0 - Rp2.500.000            Rp0 - Rp2.500.000        ShopeePay
# 1            Rp0 - Rp2.500.000            Rp0 - Rp2.500.000              Ovo
# 2            Rp0 - Rp2.500.000            Rp0 - Rp2.500.000              Ovo
# 3                >Rp20.000.000  Rp10.000.000 - Rp20.000.000              Ovo
# 4  Rp10.000.000 - Rp20.000.000  Rp10.000.000 - Rp20.000.000              Ovo
#
#   favorite_ride_hailing_app pengeluaran_ewallet_sebulan tingkat_konsumerisme  \
# ...

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster2['jenis_kelamin'].value_counts().index, y=cluster2.jenis_kelamin.value_counts())
ax.set_title('Distribusi Jenis Kelamin Cluster 2')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_2/distribusi Jenis Kelamin cluster 2.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster2['usia'].value_counts().index, y=cluster2.usia.value_counts())
ax.set_title('Distribusi Usia Cluster 2')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_2/distribusi usia cluster 2.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster2['pekerjaan'].value_counts().index, y=cluster2.pekerjaan.value_counts())
ax.set_title('Distribusi pekerjaan Cluster 2')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_2/distribusi pekerjaan cluster 2.jpg')

# %%
plt.figure(figsize=(11,5))
ax = sns.barplot(x=cluster2['pendapatan_per_bulan'].value_counts().index, y=cluster2.pendapatan_per_bulan.value_counts())
ax.set_title('Distribusi Pendapatan Per Bulan Cluster 2')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_2/distribusi Pendapatan Per Bulan cluster 2.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster2['pengeluaran_per_bulan'].value_counts().index, y=cluster2.pengeluaran_per_bulan.value_counts())
ax.set_title('Distribusi Pengeluaran Per Bulan Cluster 2')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_2/distribusi Pengeluaran Per Bulan cluster 2.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster2['tingkat_konsumerisme'].value_counts().index, y=cluster2.tingkat_konsumerisme.value_counts())
ax.set_title('Distribusi Tingkat Konsumerisme Cluster 2')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_2/distribusi Tingkat Konsumerisme cluster 2.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster2['favorite_ewallet'].value_counts().index, y=cluster2.favorite_ewallet.value_counts())
ax.set_title('Distribusi E-Wallet Paling Sering Digunakan Cluster 2')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_2/distribusi E-Wallet Paling Sering Digunakan cluster 2.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster2['favorite_ride_hailing_app'].value_counts().index, y=cluster2.favorite_ride_hailing_app.value_counts())
ax.set_title('Distribusi Ride Hailing App Paling Sering Digunakan Cluster 2')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_2/distribusi Ride Hailing App Paling Sering Digunakan cluster 2.jpg')

# %%
plt.figure(figsize=(13,5))
ax = sns.barplot(x=cluster2['pengeluaran_ewallet_sebulan'].value_counts().index, y=cluster2.pengeluaran_ewallet_sebulan.value_counts())
ax.set_title('Distribusi Pengeluaran E-Wallet Per Bulan Cluster 2')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_2/distribusi Pengeluaran E-Wallet Per Bulan cluster 2.jpg')

# %% [markdown]
# <h3>CLUSTER 3<h3>

# %%
cluster3 = pd.read_excel('cluster3.xlsx')
cluster3.head()
# Out:
#    Unnamed: 0  index jenis_kelamin           usia          pekerjaan  \
# 0           0      1          Pria  26 - 35 tahun     Pegawai Swasta
# 1           1      3          Pria  18 - 25 tahun  Pelajar/Mahasiswa
# 2           2     10          Pria  26 - 35 tahun     Pegawai Swasta
# 3           3     13        Wanita  18 - 25 tahun  Pelajar/Mahasiswa
# 4           4     14        Wanita  18 - 25 tahun     Pegawai Swasta
#
#          pendapatan_per_bulan      pengeluaran_per_bulan favorite_ewallet  \
# 0  Rp5.000.000 - Rp10.000.000  Rp2.500.000 - Rp5.000.000            GoPay
# 1  Rp5.000.000 - Rp10.000.000  Rp2.500.000 - Rp5.000.000            GoPay
# 2  Rp5.000.000 - Rp10.000.000  Rp2.500.000 - Rp5.000.000            GoPay
# 3   Rp2.500.000 - Rp5.000.000  Rp2.500.000 - Rp5.000.000            GoPay
# 4  Rp5.000.000 - Rp10.000.000  Rp2.500.000 - Rp5.000.000            GoPay
#
#   favorite_ride_hailing_app pengeluaran_ewallet_sebulan tingkat_konsumerisme  \
# ...

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster3['jenis_kelamin'].value_counts().index, y=cluster3.jenis_kelamin.value_counts())
ax.set_title('Distribusi Jenis Kelamin Cluster 3')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_3/distribusi Jenis Kelamin cluster3.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster3['usia'].value_counts().index, y=cluster3.usia.value_counts())
ax.set_title('Distribusi Usia Cluster 3')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_3/distribusi usia cluster 3.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster2['pekerjaan'].value_counts().index, y=cluster2.pekerjaan.value_counts())
ax.set_title('Distribusi Pekerjaan Cluster 2')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_3/distribusi Pekerjaan cluster 2.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster3['pendapatan_per_bulan'].value_counts().index, y=cluster3.pendapatan_per_bulan.value_counts())
ax.set_title('Distribusi Pendapatan Per Bulan Cluster 3')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_3/distribusi Pendapatan Per Bulan cluster 3.jpg')

# %%
plt.figure(figsize=(11,5))
ax = sns.barplot(x=cluster3['pengeluaran_per_bulan'].value_counts().index, y=cluster3.pengeluaran_per_bulan.value_counts())
ax.set_title('Distribusi Pengeluaran Per Bulan Cluster 3')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_3/distribusi Pengeluaran Per Bulan cluster 3.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster3['tingkat_konsumerisme'].value_counts().index, y=cluster3.tingkat_konsumerisme.value_counts())
ax.set_title('Distribusi Tingkat Konsumerisme Cluster 3')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_3/distribusi Tingkat Konsumerisme cluster 3.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster3['favorite_ewallet'].value_counts().index, y=cluster3.favorite_ewallet.value_counts())
ax.set_title('Distribusi E-Wallet Paling Sering Digunakan Cluster 3')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_3/distribusi E-Wallet Paling Sering Digunakan cluster 3.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster3['favorite_ride_hailing_app'].value_counts().index, y=cluster3.favorite_ride_hailing_app.value_counts())
ax.set_title('Distribusi Ride Hailing App Paling Sering Digunakan Cluster 3')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_3/distribusi Ride Hailing App Paling Sering Digunakan cluster 3.jpg')

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=cluster3['pengeluaran_ewallet_sebulan'].value_counts().index, y=cluster3.pengeluaran_ewallet_sebulan.value_counts())
ax.set_title('Distribusi Pengeluaran E-Wallet Per Bulan Cluster 3')
ax.bar_label(ax.containers[0])
plt.savefig('cluster_3/distribusi Pengeluaran E-Wallet Per Bulan cluster 3.jpg')
